# %% [markdown]
# ### Regression Revision

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### Step 1 : Read the dataset

# %%
import pandas as pd
df = pd.read_csv('Life Expectancy Data.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Step 2: Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
m = df.isna().sum()
m[m>0]
# Out:
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# Hepatitis B                        553
#  BMI                                34
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 3 : Seperate X and Y(Life Expectancy)

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
X = df.drop(columns=['Life expectancy '])
Y = df[['Life expectancy ']]

# %%
X.head()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0               71.279624         65.0      1154   19.1  ...    6.0
# 1               73.523582         62.0       492   18.6  ...   58.0
# 2               73.219243         64.0       430   18.1  ...   62.0
# 3               78.184215         67.0      2787   17.6  ...   67.0
# 4                7.097109         68.0      3013   17.2  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# 1               8.18         62.0        0.1  612.696514    327582.0
# 2               8.13         64.0        0.1  631.744976  31731688.0
# 3               8.52         67.0        0.1  669.959000   3696958.0
# 4               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 21 columns]

# %%
Y.head()
# Out:
#    Life expectancy
# 0              65.0
# 1              59.9
# 2              59.9
# 3              59.5
# 4              59.2

# %%
ymean = Y.mean()[0]
Y['Life expectancy '] = Y['Life expectancy '].fillna(ymean)

# %%
Y.isna().sum()
# Out:
# Life expectancy     0
# dtype: int64

# %% [markdown]
# ### Step 4 : Seperate cat and con features for X

# %%
cat = list(X.columns[X.dtypes=='object'])
con = list(X.columns[X.dtypes!='object'])

# %%
cat
# Out:
# ['Country', 'Status']

# %%
con
# Out:
# ['Year',
#  'Adult Mortality',
#  'infant deaths',
#  'Alcohol',
#  'percentage expenditure',
#  'Hepatitis B',
#  'Measles ',
#  ' BMI ',
#  'under-five deaths ',
#  'Polio',
#  'Total expenditure',
#  'Diphtheria ',
#  ' HIV/AIDS',
#  'GDP',
#  'Population',
#  ' thinness  1-19 years',
#  ' thinness 5-9 years',
#  'Income composition of resources',
#  'Schooling']

# %% [markdown]
# ### Create a feature selection pipeline for X

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
num_pipe1 = Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
                            ('scaler', StandardScaler())])

# %%
cat_pipe1 = Pipeline(steps=[('impute', SimpleImputer(strategy='most_frequent')),
                            ('ordinal', OrdinalEncoder())])

# %%
pre1 = ColumnTransformer([('num', num_pipe1, con),
                          ('cat', cat_pipe1, cat)]).set_output(transform='pandas')

# %%
pre1
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Year', 'Adult Mortality', 'infant deaths',
#                                   'Alcohol', 'percentage expenditure',
#                                   'Hepatitis B', 'Measles ', ' BMI ',
#                                   'under-five deaths ', 'Polio',
#                                   'Total expenditure', 'Diphtheria ',
#                                   ' HIV/AIDS', 'GDP', 'Population',
#                                   ' thinness  1-19 years',
#                                   ' thinness 5-9 years',
#                                   'Income composition of resources',
#                                   'Schooling']),
#                                 ('cat',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ordinal',
#                                                   OrdinalEncoder())]),
#                                  ['Country', 'Status'])])

# %%
X_pre = pre1.fit_transform(X)
X_pre.head()
# Out:
#    num__Year  num__Adult Mortality  num__infant deaths  num__Alcohol  \
# 0   1.621762              0.792119            0.268824     -1.156989
# 1   1.404986              0.856601            0.285786     -1.156989
# 2   1.188210              0.832421            0.302749     -1.156989
# 3   0.971434              0.864662            0.328193     -1.156989
# 4   0.754658              0.888843            0.345155     -1.156989
#
#    num__percentage expenditure  num__Hepatitis B  num__Measles   num__ BMI   \
# 0                    -0.335570         -0.783807      -0.110384   -0.967349
# 1                    -0.334441         -0.914281      -0.168124   -0.992434
# 2                    -0.334594         -0.827298      -0.173531   -1.017519
# 3                    -0.332096         -0.696824       0.032045   -1.042605
# 4                    -0.367862         -0.653333       0.051757   -1.062673
#
#    num__under-five deaths   num__Polio  ...  num__Diphtheria   num__ HIV/AIDS  \
# 0                 0.255359   -3.279423  ...         -0.735391       -0.323445
# 1                 0.274060   -1.053699  ...         -0.862233       -0.323445
# 2                 0.292761   -0.882489  ...         -0.777671       -0.323445
# 3                 0.317696   -0.668478  ...         -0.650830       -0.323445
# 4                 0.342631   -0.625675  ...         -0.608549       -0.323445
#
#    num__GDP  num__Population  num__ thinness  1-19 years  \
# 0 -0.453371         0.435183                    2.815209
# 1 -0.451232        -0.183349                    2.883439
# 2 -0.449799         0.398066                    2.928926
# 3 -0.446924        -0.120968                    2.974413
# 4 -0.492539        -0.134268                    3.042643
#
#    num__ thinness 5-9 years  num__Income composition of resources  \
# 0                  2.775386                             -0.737973
# 1                  2.819978                             -0.752600
# 2                  2.864570                             -0.781853
# 3                  2.931458                             -0.815982
# 4                  2.976051                             -0.859862
#
#    num__Schooling  cat__Country  cat__Status
# 0       -0.585017           0.0          1.0
# 1       -0.615649           0.0          1.0
# 2       -0.646281           0.0          1.0
# 3       -0.676912           0.0          1.0
# 4       -0.768808           0.0          1.0
#
# [5 rows x 21 columns]

# %%
X_pre.isna().sum()
# Out:
# num__Year                               0
# num__Adult Mortality                    0
# num__infant deaths                      0
# num__Alcohol                            0
# num__percentage expenditure             0
# num__Hepatitis B                        0
# num__Measles                            0
# num__ BMI                               0
# num__under-five deaths                  0
# num__Polio                              0
# num__Total expenditure                  0
# num__Diphtheria                         0
# num__ HIV/AIDS                          0
# num__GDP                                0
# num__Population                         0
# num__ thinness  1-19 years              0
# num__ thinness 5-9 years                0
# num__Income composition of resources    0
# num__Schooling                          0
# cat__Country                            0
# cat__Status                             0
# dtype: int64

# %% [markdown]
# ### Perform feature selection by Forward selection

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
sel = SequentialFeatureSelector(lr, direction='forward', n_features_to_select='auto')
sel.fit_transform(X_pre, Y)
sel_cols = sel.get_feature_names_out()
sel_cols
# Out:
# array(['num__Adult Mortality', 'num__Hepatitis B', 'num__ BMI ',
#        'num__Polio', 'num__Diphtheria ', 'num__ HIV/AIDS', 'num__GDP',
#        'num__Income composition of resources', 'num__Schooling',
#        'cat__Status'], dtype=object)

# %%
len(sel_cols)
# Out:
# 10

# %%
sel_cols[0]
# Out:
# 'num__Adult Mortality'

# %%
sel_cols[0].split('__')
# Out:
# ['num', 'Adult Mortality']

# %%
sel_cols[0].split('__')[1]
# Out:
# 'Adult Mortality'

# %%
imp_cols = []
for i in sel_cols:
    s = i.split('__')[1]
    imp_cols.append(s)

# %%
imp_cols
# Out:
# ['Adult Mortality',
#  'Hepatitis B',
#  ' BMI ',
#  'Polio',
#  'Diphtheria ',
#  ' HIV/AIDS',
#  'GDP',
#  'Income composition of resources',
#  'Schooling',
#  'Status']

# %%
X_sel = X[imp_cols]
X_sel.head()
# Out:
#    Adult Mortality  Hepatitis B   BMI   Polio  Diphtheria    HIV/AIDS  \
# 0            263.0         65.0   19.1    6.0         65.0        0.1
# 1            271.0         62.0   18.6   58.0         62.0        0.1
# 2            268.0         64.0   18.1   62.0         64.0        0.1
# 3            272.0         67.0   17.6   67.0         67.0        0.1
# 4            275.0         68.0   17.2   68.0         68.0        0.1
#
#           GDP  Income composition of resources  Schooling      Status
# 0  584.259210                            0.479       10.1  Developing
# 1  612.696514                            0.476       10.0  Developing
# 2  631.744976                            0.470        9.9  Developing
# 3  669.959000                            0.463        9.8  Developing
# 4   63.537231                            0.454        9.5  Developing

# %% [markdown]
# ### Step 7 : Seperate categorical and continuous features for X_sel

# %%
cat_sel = list(X_sel.columns[X_sel.dtypes=='object'])
con_sel = list(X_sel.columns[X_sel.dtypes!='object'])

# %%
cat_sel
# Out:
# ['Status']

# %%
con_sel
# Out:
# ['Adult Mortality',
#  'Hepatitis B',
#  ' BMI ',
#  'Polio',
#  'Diphtheria ',
#  ' HIV/AIDS',
#  'GDP',
#  'Income composition of resources',
#  'Schooling']

# %% [markdown]
# ### Step 8 : Create a final preprocessing pipeline
# Cat - OneHotEncoding

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
num_pipe2 = Pipeline(steps=[('impute', SimpleImputer(strategy='median')),
                            ('scaler', StandardScaler())])

# %%
cat_pipe2 = Pipeline(steps=[('impute', SimpleImputer(strategy='most_frequent')),
                            ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %%
pre2 = ColumnTransformer([('num', num_pipe2, con_sel),
                          ('cat', cat_pipe2, cat_sel)]).set_output(transform='pandas')

# %%
X_sel_pre = pre2.fit_transform(X_sel)
X_sel_pre.head()
# Out:
#    num__Adult Mortality  num__Hepatitis B  num__ BMI   num__Polio  \
# 0              0.792119         -0.783807   -0.967349   -3.279423
# 1              0.856601         -0.914281   -0.992434   -1.053699
# 2              0.832421         -0.827298   -1.017519   -0.882489
# 3              0.864662         -0.696824   -1.042605   -0.668478
# 4              0.888843         -0.653333   -1.062673   -0.625675
#
#    num__Diphtheria   num__ HIV/AIDS  num__GDP  \
# 0         -0.735391       -0.323445 -0.453371
# 1         -0.862233       -0.323445 -0.451232
# 2         -0.777671       -0.323445 -0.449799
# 3         -0.650830       -0.323445 -0.446924
# 4         -0.608549       -0.323445 -0.492539
#
#    num__Income composition of resources  num__Schooling  \
# 0                             -0.737973       -0.585017
# 1                             -0.752600       -0.615649
# 2                             -0.781853       -0.646281
# 3                             -0.815982       -0.676912
# 4                             -0.859862       -0.768808
#
#    cat__Status_Developed  cat__Status_Developing
# 0                    0.0                     1.0
# 1                    0.0                     1.0
# 2                    0.0                     1.0
# 3                    0.0                     1.0
# 4                    0.0                     1.0

# %% [markdown]
# ### Apply train test split
# (test data - unseen data to my model 20% - 30%)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_sel_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.shape
# Out:
# (2350, 11)

# %%
xtest.shape
# Out:
# (588, 11)

# %%
xtrain.head()
# Out:
#       num__Adult Mortality  num__Hepatitis B  num__ BMI   num__Polio  \
# 456              -0.312140          0.564426   -0.646257    0.658396
# 462              -0.102572          0.390460   -0.816837    0.358779
# 2172             -0.175115          0.694900    0.306985    0.701199
# 2667             -1.222952          0.651408    1.049510    0.658396
# 381              -0.562009          0.694900   -0.520830    0.701199
#
#       num__Diphtheria   num__ HIV/AIDS  num__GDP  \
# 456           0.659867       -0.224960 -0.263213
# 462          -3.103102       -0.185566 -0.401873
# 2172          0.702148       -0.323445 -0.364409
# 2667          0.659867       -0.323445 -0.181434
# 381           0.490745       -0.323445  0.769854
#
#       num__Income composition of resources  num__Schooling  \
# 456                              -0.138280       -0.033645
# 462                              -0.333302       -0.309331
# 2172                              0.500419        0.272673
# 2667                              0.437036        0.824045
# 381                               0.924592        0.395200
#
#       cat__Status_Developed  cat__Status_Developing
# 456                     0.0                     1.0
# 462                     0.0                     1.0
# 2172                    0.0                     1.0
# 2667                    0.0                     1.0
# 381                     0.0                     1.0

# %%
ytrain.head()
# Out:
#       Life expectancy
# 456               72.3
# 462               73.0
# 2172              74.6
# 2667              74.9
# 381               74.8

# %%
xtest.head()
# Out:
#       num__Adult Mortality  num__Hepatitis B  num__ BMI   num__Polio  \
# 2546             -0.336321         -0.000962    0.507668    0.016360
# 650              -0.416924          0.390460    0.989306    0.572791
# 1740             -0.320200         -3.219323    0.944152    0.401582
# 177              -1.271314          0.651408    1.230125    0.658396
# 1377              2.122066          0.390460   -1.203151   -3.193818
#
#       num__Diphtheria   num__ HIV/AIDS  num__GDP  \
# 2546         -3.145382       -0.323445 -0.364763
# 650           0.575306       -0.323445  0.357437
# 1740          0.406184       -0.323445 -0.049222
# 177           0.659867       -0.323445  1.381931
# 1377         -0.016622        3.222012 -0.494011
#
#       num__Income composition of resources  num__Schooling  \
# 2546                              0.027489       -0.186804
# 650                               0.744196        0.578991
# 1740                              0.641810        0.487095
# 177                               0.924592        0.762781
# 1377                             -0.889116       -1.105757
#
#       cat__Status_Developed  cat__Status_Developing
# 2546                    0.0                     1.0
# 650                     1.0                     0.0
# 1740                    0.0                     1.0
# 177                     0.0                     1.0
# 1377                    0.0                     1.0

# %%
ytest.head()
# Out:
#       Life expectancy
# 2546              73.7
# 650               75.9
# 1740              74.2
# 177               76.8
# 1377              51.9

# %% [markdown]
# ### Algo evaluation for above data

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor

# %%
dct = {'Linear' : LinearRegression(),
       'Ridge': Ridge(),
       'Lasso': Lasso(),
       'Decision Tree':DecisionTreeRegressor(),
       'Random Forest':RandomForestRegressor(),
       'Gradient Boost':GradientBoostingRegressor()}

# %%
dct.items()
# Out:
# dict_items([('Linear', LinearRegression()), ('Ridge', Ridge()), ('Lasso', Lasso()), ('Decision Tree', DecisionTreeRegressor()), ('Random Forest', RandomForestRegressor()), ('Gradient Boost', GradientBoostingRegressor())])

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
for name, model in dct.items():
    # Train the model
    model.fit(xtrain, ytrain)
    # Predict the results for train and test
    ypred_tr = model.predict(xtrain)
    ypred_ts = model.predict(xtest)
    # Get R2 score
    r2_tr = r2_score(ytrain, ypred_tr)
    r2_ts = r2_score(ytest, ypred_ts)
    # Get the cross validated results
    scores = cross_val_score(model, xtrain, ytrain, cv=5, scoring='r2')
    r2_cv = scores.mean()
    # Print above results
    print(f'Model Name : {name}\n')
    print(f'Training R2 : {r2_tr:.4f}')
    print(f'Testing R2 : {r2_ts:.4f}')
    print(f'CV R2 : {r2_cv:.4f}')
    print('\n===================================================\n')
# Out:
# Model Name : Linear
#
# Training R2 : 0.8060
# Testing R2 : 0.8115
# CV R2 : 0.8000
#
# ===================================================
#
# Model Name : Ridge
#
# Training R2 : 0.8060
# Testing R2 : 0.8115
# CV R2 : 0.8000
#
# ===================================================
#
# Model Name : Lasso
#
# Training R2 : 0.7718
# Testing R2 : 0.7741
# CV R2 : 0.7665
#
# ===================================================
#
# Model Name : Decision Tree
#
# Training R2 : 1.0000
# Testing R2 : 0.9144
# CV R2 : 0.9020
#
# ===================================================
#
# Model Name : Random Forest
#
# Training R2 : 0.9938
# Testing R2 : 0.9635
# CV R2 : 0.9503
#
# ===================================================
#
# Model Name : Gradient Boost
#
# Training R2 : 0.9508
# Testing R2 : 0.9418
# CV R2 : 0.9304
#
# ===================================================

# %% [markdown]
# ### Select Randomforest model as it has highest cross validated score of 0.9503

# %% [markdown]
# ### Hyperparater tuning - n_estimators, max_depth, min_samples_split

# %%
params = {'n_estimators':[10, 50, 100, 200, 300],
          'max_depth':[2, 3, 4, 5, 6],
          'min_samples_split':[5, 6, 7, 8, 9, 10, 11, 12]}

# %%
from sklearn.model_selection import RandomizedSearchCV
rf = RandomForestRegressor()
rscv = RandomizedSearchCV(rf, param_distributions=params, cv=5, scoring='r2')
rscv.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(),
#                    param_distributions={'max_depth': [2, 3, 4, 5, 6],
#                                         'min_samples_split': [5, 6, 7, 8, 9, 10,
#                                                               11, 12],
#                                         'n_estimators': [10, 50, 100, 200,
#                                                          300]},
#                    scoring='r2')

# %%
rscv.best_params_
# Out:
# {'n_estimators': 100, 'min_samples_split': 10, 'max_depth': 4}

# %%
rscv.best_score_
# Out:
# 0.8909540845479608

# %%
best_rf = rscv.best_estimator_
best_rf
# Out:
# RandomForestRegressor(max_depth=4, min_samples_split=10)

# %%
best_rf.score(xtrain, ytrain)
# Out:
# 0.9057067655724645

# %%
best_rf.score(xtest, ytest)
# Out:
# 0.8993440854743664

# %% [markdown]
# ### After tuning model score DOES NOT Improve hence use the base model

# %%
base_rf = RandomForestRegressor()
base_rf.fit(xtrain, ytrain)
# Out:
# RandomForestRegressor()

# %%
base_rf.score(xtrain, ytrain)
# Out:
# 0.9938417393774945

# %%
base_rf.score(xtest, ytest)
# Out:
# 0.9630647954799881

# %% [markdown]
# ### Evaluate the model (mse, rmse, mae, r2_score)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
ypred_tr = base_rf.predict(xtrain)
ypred_ts = base_rf.predict(xtest)

# %%
ypred_tr[0:5]
# Out:
# array([72.576, 71.356, 74.605, 74.991, 75.122])

# %%
ytrain.head()
# Out:
#       Life expectancy
# 456               72.3
# 462               73.0
# 2172              74.6
# 2667              74.9
# 381               74.8

# %%
ypred_ts[0:5]
# Out:
# array([72.925, 75.996, 75.283, 75.798, 51.802])

# %%
ytest.head()
# Out:
#       Life expectancy
# 2546              73.7
# 650               75.9
# 1740              74.2
# 177               76.8
# 1377              51.9

# %%
ts_mse = mean_squared_error(ytest, ypred_ts)
ts_mse
# Out:
# 3.1998916712231495

# %%
ts_rmse = ts_mse**(1/2)
ts_rmse
# Out:
# 1.7888241029299525

# %%
ts_mae = mean_absolute_error(ytest, ypred_ts)
ts_mae
# Out:
# 1.2143517515612792

# %%
ts_r2 = r2_score(ytest, ypred_ts)
ts_r2
# Out:
# 0.9630647954799881

# %% [markdown]
# ### Cross validation score for r2

# %%
scores = cross_val_score(base_rf, xtrain, ytrain, cv=5, scoring='r2')
scores
# Out:
# array([0.9556234 , 0.96139276, 0.95140771, 0.94851779, 0.93491454])

# %%
scores.mean()
# Out:
# 0.9503712410052497
